# %% [markdown]
# ##  Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("/content/Video_Games.csv")

# %% [markdown]
# ## EDA

# %%
df.head(10) # display 10 rows (as default = first 5)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
df.tail(10) # display last 10 rows
# Out:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# 16710           2003.0     Shooter         Infogrames      0.01      0.00
# ...

# %%
df.info() # information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  Developer        10096 non-null  object
# dtypes: float64(8), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Data Cleaning

# %%
df.columns # Display columns name
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'Developer'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower() # Lowercase columns name

# %%
df.isna().sum() # Check for null values
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# publisher            54
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# global_sales          0
# critic_score       8582
# critic_count       8582
# user_score         6704
# developer          6623
# dtype: int64

# %%
df.drop(df[df["name"].isna()].index,inplace=True) # Drop nulls in name column

# %%
df.isna().sum() # Check for null
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# publisher            54
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# global_sales          0
# critic_score       8580
# critic_count       8580
# user_score         6702
# developer          6621
# dtype: int64

# %%
df.dropna(subset = ['year_of_release'] , inplace = True) # Drop nulls in year of release column

# %%
df['year_of_release'].astype(int) # Change dtype to integer
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16714    2016
# 16715    2006
# 16716    2016
# 16717    2003
# 16718    2016
# Name: year_of_release, Length: 16448, dtype: int64

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# publisher            32
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# global_sales          0
# critic_score       8465
# critic_count       8465
# user_score         6608
# developer          6541
# dtype: int64

# %%
df.dropna(subset=['publisher'], inplace=True) # Drop Nulls value in publisher column

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# publisher             0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# global_sales          0
# critic_score       8434
# critic_count       8434
# user_score         6579
# developer          6512
# dtype: int64

# %%
df.dropna(subset = ["platform"] , inplace = True) # Drop nulls in platform columns

# %%
df["critic_score"] = df["critic_score"].fillna(df["critic_score"].mean()) # Replace null in critic_score column with mean

# %%
df["critic_count"] = df["critic_count"].fillna(df["critic_count"].mean()) # Replace null in critic_count column with mean

# %%
df["critic_count"] = df["critic_count"].astype(int) # After replacing nulls, change type to integer

# %%
df['user_score']=pd.to_numeric(df['user_score'],errors='coerce')
user_score_mean=df['user_score'].mean()
df['user_score']=df['user_score'].fillna(user_score_mean)

# %%
df.drop("developer" , axis = 1 , inplace = True) # Drop developer column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16416 entries, 0 to 16718
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16416 non-null  object
#  1   platform         16416 non-null  object
#  2   year_of_release  16416 non-null  float64
#  3   genre            16416 non-null  object
#  4   publisher        16416 non-null  object
#  5   na_sales         16416 non-null  float64
#  6   eu_sales         16416 non-null  float64
#  7   jp_sales         16416 non-null  float64
#  8   other_sales      16416 non-null  float64
#  9   global_sales     16416 non-null  float64
#  10  critic_score     16416 non-null  float64
#  11  critic_count     16416 non-null  int64
#  12  user_score       16416 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 1.8+ MB

# %%
df["year_of_release"] = pd.to_datetime(df["year_of_release"]) # Change dtype to datetime

# %%
sales_yearly = df.groupby("year_of_release")["global_sales"].sum()
plt.plot(sales_yearly.index, sales_yearly.values, color = "black" , marker = "o", markerfacecolor = "red")
plt.xlabel("Year of Release")
plt.ylabel("Total Global Sales (millions)")
plt.title("Total Global Sales Over the Years")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16416 entries, 0 to 16718
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16416 non-null  object
#  1   platform         16416 non-null  object
#  2   year_of_release  16416 non-null  datetime64[ns]
#  3   genre            16416 non-null  object
#  4   publisher        16416 non-null  object
#  5   na_sales         16416 non-null  float64
#  6   eu_sales         16416 non-null  float64
#  7   jp_sales         16416 non-null  float64
#  8   other_sales      16416 non-null  float64
#  9   global_sales     16416 non-null  float64
#  10  critic_score     16416 non-null  float64
#  11  critic_count     16416 non-null  int64
#  12  user_score       16416 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(4)
# memory usage: 1.8+ MB

# %%
df.duplicated().sum() # Check for duplicates
# Out:
# 0

# %%
df['year']= df['year_of_release'].dt.year # create year column

# %%
df['month']=df['year_of_release'].dt.month # create  month column

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#                      year_of_release      na_sales      eu_sales  \
# count                          16416  16416.000000  16416.000000
# mean   2006-06-28 19:13:41.052631552      0.264129      0.146034
# min              1980-01-01 00:00:00      0.000000      0.000000
# 25%              2003-01-01 00:00:00      0.000000      0.000000
# 50%              2007-01-01 00:00:00      0.080000      0.020000
# 75%              2010-01-01 00:00:00      0.240000      0.110000
# max              2020-01-01 00:00:00     41.360000     28.960000
# std                              NaN      0.819028      0.507134
#
#            jp_sales   other_sales  global_sales  critic_score  critic_count  \
# count  16416.000000  16416.000000  16416.000000  16416.000000  16416.000000
# mean       0.078623      0.047670      0.536708     68.997119     26.214425
# min        0.000000      0.000000      0.010000     13.000000      3.000000
# ...

# %%
df.describe(include = "object")
# Out:
#                                name platform   genre        publisher
# count                         16416    16416   16416            16416
# unique                        11397       31      12              579
# top     Need for Speed: Most Wanted      PS2  Action  Electronic Arts
# freq                             12     2127    3307             1344

# %%
df.to_excel("Video_Games_Cleaned.xlsx", index = False) # Export data after cleaning

# %%
df.select_dtypes(include = "number").corr()
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# na_sales      1.000000  0.766539  0.451175     0.638502      0.941238
# eu_sales      0.766539  1.000000  0.435877     0.722679      0.901665
# jp_sales      0.451175  0.435877  1.000000     0.291489      0.613305
# other_sales   0.638502  0.722679  0.291489     1.000000      0.748907
# global_sales  0.941238  0.901665  0.613305     0.748907      1.000000
# critic_score  0.184476  0.194947  0.091908     0.184736      0.200815
# critic_count  0.229931  0.247796  0.106845     0.237589      0.251170
# user_score    0.065538  0.048891  0.075543     0.053044      0.071747
# year         -0.092346  0.003922 -0.168614     0.037686     -0.076337
# month              NaN       NaN       NaN          NaN           NaN
#
#               critic_score  critic_count  user_score      year  month
# na_sales          0.184476      0.229931    0.065538 -0.092346    NaN
# ...

# %% [markdown]
# # Business Questions

# %% [markdown]
# ## Q1 - Determine strong positive correlation between different columns?

# %%
plt.scatter(df["global_sales"] , df["na_sales"])

# %%
plt.scatter(df["global_sales"] , df["eu_sales"])

# %%
plt.scatter(df["global_sales"] , df["jp_sales"])

# %%
plt.scatter(df["global_sales"] , df["other_sales"])

# %% [markdown]
# ## Q2- How many games are in the dataset?

# %%
df["name"].count()
# Out:
# 16416

# %%
plt.bar(["Total Games"], df["name"].count())
plt.ylabel("Count")
plt.title("Total Number of Games")
plt.show()

# %% [markdown]
# ## Q3- Which platform has the most games?

# %%
df["platform"].value_counts().head(1)
# Out:
# platform
# PS2    2127
# Name: count, dtype: int64

# %% [markdown]
# ## Q4- What is the lowest common genre?

# %%
df["genre"].value_counts().tail(1)
# Out:
# genre
# Puzzle    569
# Name: count, dtype: int64

# %% [markdown]
# ## Q5- which year has the most number of released games?

# %%
df["year"].value_counts().head(1)
# Out:
# year
# 2008    1427
# Name: count, dtype: int64

# %% [markdown]
# ## Q6- What is the best-selling game worldwide?

# %%
df.groupby("name")["global_sales"].sum().sort_values(ascending = False).head(1)
# Out:
# name
# Wii Sports    82.53
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q7- Which publisher has released the most games?

# %%
df.groupby("publisher")["name"].count().sort_values(ascending = False).head(1)
# Out:
# publisher
# Electronic Arts    1344
# Name: name, dtype: int64

# %% [markdown]
# ## Q8- Which platform has the highest global sales?

# %%
df.groupby("platform")["global_sales"].sum().sort_values(ascending = False).head(1)
# Out:
# platform
# PS2    1233.46
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q9- Which year had the highest global sales?

# %%
df.groupby("year")["global_sales"].sum().sort_values(ascending = False).head(1)
# Out:
# year
# 2008    671.79
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q10- Which game has the highest sales in Japan?

# %%
df.groupby("name")["jp_sales"].sum().sort_values(ascending = False).head(1)
# Out:
# name
# Pokemon Red/Pokemon Blue    10.22
# Name: jp_sales, dtype: float64

# %% [markdown]
# ## Q11- What is the average global sales per game?

# %%
df.groupby('name')['global_sales'].mean().sort_values(ascending=False).head(1)
# Out:
# name
# Wii Sports    82.53
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q12- How many unique publishers are in the dataset?

# %%
df["publisher"].nunique()
# Out:
# 579

# %% [markdown]
# ## Q13- How many unique platforms are in the dataset?

# %%
df["platform"].nunique()
# Out:
# 31

# %% [markdown]
# ## Q14- What is the most successful publisher based on total global sales?

# %%
df.groupby("publisher")["global_sales"].sum().sort_values(ascending = False).head(1)
# Out:
# publisher
# Nintendo    1786.72
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q15- Which genre has the highest average global sales?

# %%
df.groupby("genre")["global_sales"].mean().sort_values(ascending = False).head(1)
# Out:
# genre
# Platform    0.940615
# Name: global_sales, dtype: float64

# %% [markdown]
# ## Q16- What percentage of total global sales come from the top 10 best-selling games?

# %%
total_global_sales = df["global_sales"].sum()
top_10 = df.nlargest(10, "global_sales")["global_sales"].sum()
percentage = round(top_10 / total_global_sales * 100, 2)
print(percentage,"%")
# Out:
# 4.18 %

# %% [markdown]
# # Q17- What is the sum of global sales in each year per genere?

# %%
pivoted_df = df.pivot_table(index='year', columns='genre', values='global_sales', aggfunc='sum')
pivoted_df
# Out:
# genre  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# year
# 1980     0.34        NaN      0.77   2.71       NaN     NaN     NaN
# 1981    14.84        NaN       NaN    NaN      6.93    2.24    0.48
# 1982     6.52        NaN       NaN   0.87      5.03   10.03    1.57
# 1983     2.86       0.40       NaN   2.14      6.93    0.78     NaN
# 1984     1.85        NaN       NaN   1.45      0.69    3.14    5.95
# 1985     3.52        NaN      1.05    NaN     43.17    3.21     NaN
# 1986    13.74        NaN       NaN    NaN      9.39     NaN    1.96
# 1987     1.12       4.38      5.42    NaN      1.74     NaN     NaN
# 1988     1.75        NaN       NaN    NaN     27.73    5.58    2.14
# 1989     4.64        NaN       NaN   1.28     20.66   37.75     NaN
# 1990     6.39        NaN       NaN    NaN     22.97    6.00    6.26
# 1991     6.76       2.24      0.39   0.08      7.64    3.24    1.14
# 1992     3.83      12.24     15.25   4.94     13.42    4.84    9.04
# ...

# %%
pivoted_df.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # Q18- Which game has the biggest difference between critic score and user score?

# %%
df['diff_score'] = df['critic_score'] - df['user_score']
df.groupby('name')['diff_score'].max().sort_values(ascending=False).head(1)
# Out:
# name
# NFL 2K1    91.0
# Name: diff_score, dtype: float64

# %% [markdown]
# # Q19- What is the difference between critic score and user score each year per platform?

# %%
pivoted_df=df.pivot_table(index='year',columns='platform',values=['diff_score'])
pivoted_df
# Out:
#          diff_score                                                         \
# platform       2600        3DO        3DS         DC         DS         GB
# year
# 1980      61.870219        NaN        NaN        NaN        NaN        NaN
# 1981      61.870219        NaN        NaN        NaN        NaN        NaN
# 1982      61.870219        NaN        NaN        NaN        NaN        NaN
# 1983      61.870219        NaN        NaN        NaN        NaN        NaN
# 1984      61.870219        NaN        NaN        NaN        NaN        NaN
# 1985      61.870219        NaN        NaN        NaN  61.870219        NaN
# 1986      61.870219        NaN        NaN        NaN        NaN        NaN
# 1987      61.870219        NaN        NaN        NaN        NaN        NaN
# 1988      61.870219        NaN        NaN        NaN        NaN  61.870219
# 1989      61.870219        NaN        NaN        NaN        NaN  61.870219
# ...

# %% [markdown]
# # Q20- Which month has the moste euro sales?

# %%
df.groupby('month')['eu_sales'].sum().sort_values(ascending=False).head(1)
# Out:
# month
# 1    2397.29
# Name: eu_sales, dtype: float64

# %% [markdown]
# # Q21- what is total global sales per platform each year?

# %%
df.groupby(['year','platform'])[['global_sales','eu_sales','other_sales','jp_sales','na_sales']].sum().sort_values(by='global_sales',ascending=False)
# Out:
#                global_sales  eu_sales  other_sales  jp_sales  na_sales
# year platform
# 2004 PS2             211.78     56.01        39.85     19.17     96.78
# 2009 Wii             207.08     58.31        17.54     16.57    114.55
# 2002 PS2             205.40     65.27        21.72     21.85     96.54
# 2003 PS2             184.29     61.20        20.69     18.88     83.54
# 2008 Wii             171.45     46.52        14.99     12.69     97.12
# ...                     ...       ...          ...       ...       ...
# 1988 PC                0.03      0.02         0.01      0.00      0.00
# 1994 3DO               0.02      0.00         0.00      0.02      0.00
# 1985 DS                0.02      0.00         0.00      0.02      0.00
# 2007 DC                0.02      0.00         0.00      0.02      0.00
# 2017 PSV               0.02      0.00         0.00      0.02      0.00
#
# [241 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
_df_11['jp_sales'].plot(kind='line', figsize=(8, 4), title='jp_sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_10['other_sales'].plot(kind='line', figsize=(8, 4), title='other_sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9['eu_sales'].plot(kind='line', figsize=(8, 4), title='eu_sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8['global_sales'].plot(kind='line', figsize=(8, 4), title='global_sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8['na_sales'].plot(kind='line', figsize=(8, 4), title='na_sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Q22- Which publisher had the best average critic score, considering only publishers with at least 20 games?

# %%
publisher_avg_score = df.groupby('publisher')['critic_score'].mean()

# %%
publisher_counts = df['publisher'].value_counts()
publisher_counts
# Out:
# publisher
# Electronic Arts                 1344
# Activision                       976
# Namco Bandai Games               935
# Ubisoft                          930
# Konami Digital Entertainment     825
#                                 ...
# Max Five                           1
# On Demand                          1
# Bomb                               1
# Detn8 Games                        1
# Red Flagship                       1
# Name: count, Length: 579, dtype: int64

# %%
filtered_publishers = publisher_counts[publisher_counts >= 20].index
filtered_publishers
# Out:
# Index(['Electronic Arts', 'Activision', 'Namco Bandai Games', 'Ubisoft',
#        'Konami Digital Entertainment', 'THQ', 'Nintendo',
#        'Sony Computer Entertainment', 'Sega', 'Take-Two Interactive', 'Capcom',
#        'Atari', 'Tecmo Koei', 'Square Enix',
#        'Warner Bros. Interactive Entertainment', 'Disney Interactive Studios',
#        'Midway Games', 'Eidos Interactive', '505 Games',
#        'Microsoft Game Studios', 'Acclaim Entertainment', 'D3Publisher',
#        'Vivendi Games', 'Codemasters', 'Idea Factory', 'Deep Silver',
#        'Nippon Ichi Software', 'Zoo Digital Publishing', 'Unknown',
#        'Majesco Entertainment', 'LucasArts', 'Rising Star Games',
#        'Hudson Soft', 'Bethesda Softworks', 'Banpresto', 'Crave Entertainment',
#        'Atlus', '5pb', 'Virgin Interactive', 'Infogrames',
#        'Ignition Entertainment', 'Focus Home Interactive',
#        'Marvelous Interactive', 'SquareSoft', 'Empire Interactive',
# ...

# %%
filtered_avg_score = publisher_avg_score[publisher_avg_score.index.isin(filtered_publishers)]
filtered_avg_score
# Out:
# publisher
# 3DO                                       63.554035
# 505 Games                                 65.480227
# 5pb                                       68.964907
# ASCII Entertainment                       68.847263
# Acclaim Entertainment                     67.639770
#                                             ...
# Virgin Interactive                        72.175421
# Vivendi Games                             67.074051
# Warner Bros. Interactive Entertainment    69.330810
# Zoo Digital Publishing                    61.113805
# Zoo Games                                 64.997642
# Name: critic_score, Length: 88, dtype: float64

# %%
best_publishers = filtered_avg_score.sort_values(ascending=False).head(1)
best_publishers
# Out:
# publisher
# Microsoft Game Studios    74.47054
# Name: critic_score, dtype: float64

# %%
best_publishers=filtered_avg_score.idxmax()
best_publishers
# Out:
# 'Microsoft Game Studios'

# %% [markdown]
# # Other Code

# %%
df.groupby("publisher").filter(lambda x: len(x) >= 20).groupby("publisher")["critic_score"].mean().sort_values(ascending=False).head(1)
# Out:
# publisher
# Microsoft Game Studios    74.47054
# Name: critic_score, dtype: float64

# %% [markdown]
# # Q23- Which Racing game has the second highest global sales?

# %%
sorted_racing_game=df[df["genre"] == "Racing"].sort_values(by='global_sales',ascending=False)

# %%
second_highest_sales=sorted_racing_game.iloc[1]
second_highest_sales['name']
# Out:
# 'Mario Kart DS'

# %% [markdown]
# # Q24- Which best PS4 sold game in Europe?

# %%
df[df['platform']=='PS4'].sort_values(by='eu_sales',ascending=False).head(1)['name']
# Out:
# 42    Grand Theft Auto V
# Name: name, dtype: object

# %% [markdown]
# # Q25- What is the percentage of published games for each publisher?

# %%
print("The percentage of published games of Nintendo is:", round(df[df['publisher']=='Nintendo'].count()['name']/df['name'].count()*100,2),"%")
# Out:
# The percentage of published games of Nintendo is: 4.26 %
